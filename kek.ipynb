# %%
from huggingface_hub import hf_hub_download
import joblib

REPO_ID = "https://github.com/daniyarzt/finBERT/tree/master"
FILENAME = "sklearn_model.joblib"

model = joblib.load(
    hf_hub_download(repo_id=REPO_ID, filename=FILENAME)
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from huggingface_hub import hf_hub_download
#       2 import joblib
#       4 REPO_ID = "https://github.com/daniyarzt/finBERT/tree/master"
#
# File ~/Documents/code/finBERT/.venv/lib/python3.9/site-packages/huggingface_hub/__init__.py:305, in _attach.<locals>.__getattr__(name)
#     303 elif name in attr_to_modules:
#     304     submod_path = f"{package_name}.{attr_to_modules[name]}"
# --> 305     submod = importlib.import_module(submod_path)
#     306     attr = getattr(submod, name)
#     308     # If the attribute lives in a file (module) with the same
#     309     # name as the attribute, ensure that the attribute and *not*
#     310     # the module is accessible on the package.
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/Documents/code/finBERT/.venv/lib/python3.9/site-packages/huggingface_hub/file_download.py:20
#      17 from typing import Any, BinaryIO, Dict, Generator, Optional, Tuple, Union
#      18 from urllib.parse import quote, urlparse
# ---> 20 import requests
#      21 from filelock import FileLock
#      22 from requests.exceptions import ConnectTimeout, ProxyError
#
# File ~/Documents/code/finBERT/.venv/lib/python3.9/site-packages/requests/__init__.py:43
#       6 """
#       7 Requests HTTP Library
#       8 ~~~~~~~~~~~~~~~~~~~~~
#    (...)
#      38 :license: Apache 2.0, see LICENSE for more details.
#      39 """
#      41 import warnings
# ---> 43 import urllib3
#      45 from .exceptions import RequestsDependencyWarning
#      47 try:
#
# File ~/Documents/code/finBERT/.venv/lib/python3.9/site-packages/urllib3/__init__.py:38
#      32 else:
#      33     # fmt: off
#      34     if (
#      35         not ssl.OPENSSL_VERSION.startswith("OpenSSL ")
#      36         or ssl.OPENSSL_VERSION_INFO < (1, 1, 1)
#      37     ):  # Defensive:
# ---> 38         raise ImportError(
#      39             "urllib3 v2.0 only supports OpenSSL 1.1.1+, currently "
#      40             f"the 'ssl' module is compiled with {ssl.OPENSSL_VERSION}. "
#      41             "See: https://github.com/urllib3/urllib3/issues/2168"
#      42         )
#      43     # fmt: on
#      44
#      45 # === NOTE TO REPACKAGERS AND VENDORS ===
#      46 # Please delete this block, this logic is only
#      47 # for urllib3 being distributed via PyPI.
#      48 # See: https://github.com/urllib3/urllib3/issues/2680
#      49 try:
#
# ImportError: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with LibreSSL 2.8.3. See: https://github.com/urllib3/urllib3/issues/2168

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")

model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from transformers import AutoTokenizer, AutoModelForSequenceClassification
#       3 tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
#       5 model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")
#
# File ~/Documents/code/finBERT/.venv/lib/python3.9/site-packages/transformers/__init__.py:26
#      23 from typing import TYPE_CHECKING
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
#      28     OptionalDependencyNotAvailable,
#      29     _LazyModule,
#    (...)
#      42     logging,
#      43 )
#      46 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File ~/Documents/code/finBERT/.venv/lib/python3.9/site-packages/transformers/dependency_versions_check.py:17
#      14 import sys
#      16 from .dependency_versions_table import deps
# ---> 17 from .utils.versions import require_version, require_version_core
#      20 # define which module versions we always want to check at run time
#      21 # (usually the ones defined in `install_requires` in setup.py)
#      22 #
#      23 # order specific notes:
#      24 # - tqdm must be checked before tokenizers
#      26 pkgs_to_check_at_runtime = "python tqdm regex requests packaging filelock numpy tokenizers".split()
#
# File ~/Documents/code/finBERT/.venv/lib/python3.9/site-packages/transformers/utils/__init__.py:30
#      21 from .constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD, IMAGENET_STANDARD_MEAN, IMAGENET_STANDARD_STD
#      22 from .doc import (
#      23     add_code_sample_docstrings,
#      24     add_end_docstrings,
#    (...)
#      28     replace_return_docstrings,
#      29 )
# ---> 30 from .generic import (
#      31     ContextManagers,
#      32     ExplicitEnum,
#      33     ModelOutput,
#      34     PaddingStrategy,
#      35     TensorType,
#      36     cached_property,
#      37     can_return_loss,
#      38     expand_dims,
#      39     find_labels,
#      40     flatten_dict,
#      41     is_jax_tensor,
#      42     is_numpy_array,
#      43     is_tensor,
#      44     is_tf_tensor,
#      45     is_torch_device,
#      46     is_torch_dtype,
#      47     is_torch_tensor,
#      48     reshape,
#      49     squeeze,
#      50     strtobool,
#      51     tensor_size,
#      52     to_numpy,
#      53     to_py_obj,
#      54     transpose,
#      55     working_or_temp_dir,
#      56 )
#      57 from .hub import (
#      58     CLOUDFRONT_DISTRIB_PREFIX,
#      59     DISABLE_TELEMETRY,
#    (...)
#      85     send_example_telemetry,
#      86 )
#      87 from .import_utils import (
#      88     ENV_VARS_TRUE_AND_AUTO_VALUES,
#      89     ENV_VARS_TRUE_VALUES,
#    (...)
#     167     torch_version,
#     168 )
#
# File ~/Documents/code/finBERT/.venv/lib/python3.9/site-packages/transformers/utils/generic.py:29
#      25 from typing import Any, ContextManager, List, Tuple
#      27 import numpy as np
# ---> 29 from .import_utils import is_flax_available, is_tf_available, is_torch_available, is_torch_fx_proxy
#      32 if is_flax_available():
#      33     import jax.numpy as jnp
#
# File ~/Documents/code/finBERT/.venv/lib/python3.9/site-packages/transformers/utils/import_utils.py:32
#      28 from typing import Any
#      30 from packaging import version
# ---> 32 from . import logging
#      33 from .versions import importlib_metadata
#      36 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File ~/Documents/code/finBERT/.venv/lib/python3.9/site-packages/transformers/utils/logging.py:35
#      23 from logging import (
#      24     CRITICAL,  # NOQA
#      25     DEBUG,  # NOQA
#    (...)
#      31     WARNING,  # NOQA
#      32 )
#      33 from typing import Optional
# ---> 35 import huggingface_hub.utils as hf_hub_utils
#      36 from tqdm import auto as tqdm_lib
#      39 _lock = threading.Lock()
#
# File ~/Documents/code/finBERT/.venv/lib/python3.9/site-packages/huggingface_hub/utils/__init__.py:32
#      30 from ._chunk_utils import chunk_iterable
#      31 from ._datetime import parse_datetime
# ---> 32 from ._errors import (
#      33     BadRequestError,
#      34     EntryNotFoundError,
#      35     GatedRepoError,
#      36     HfHubHTTPError,
#      37     LocalEntryNotFoundError,
#      38     RepositoryNotFoundError,
#      39     RevisionNotFoundError,
#      40     hf_raise_for_status,
#      41 )
#      42 from ._fixes import SoftTemporaryDirectory, yaml_dump
#      43 from ._git_credential import list_credential_helpers, set_git_credential, unset_git_credential
#
# File ~/Documents/code/finBERT/.venv/lib/python3.9/site-packages/huggingface_hub/utils/_errors.py:3
#       1 from typing import Optional
# ----> 3 from requests import HTTPError, Response
#       5 from ._fixes import JSONDecodeError
#       8 class HfHubHTTPError(HTTPError):
#
# File ~/Documents/code/finBERT/.venv/lib/python3.9/site-packages/requests/__init__.py:43
#       6 """
#       7 Requests HTTP Library
#       8 ~~~~~~~~~~~~~~~~~~~~~
#    (...)
#      38 :license: Apache 2.0, see LICENSE for more details.
#      39 """
#      41 import warnings
# ---> 43 import urllib3
#      45 from .exceptions import RequestsDependencyWarning
#      47 try:
#
# File ~/Documents/code/finBERT/.venv/lib/python3.9/site-packages/urllib3/__init__.py:38
#      32 else:
#      33     # fmt: off
#      34     if (
#      35         not ssl.OPENSSL_VERSION.startswith("OpenSSL ")
#      36         or ssl.OPENSSL_VERSION_INFO < (1, 1, 1)
#      37     ):  # Defensive:
# ---> 38         raise ImportError(
#      39             "urllib3 v2.0 only supports OpenSSL 1.1.1+, currently "
#      40             f"the 'ssl' module is compiled with {ssl.OPENSSL_VERSION}. "
#      41             "See: https://github.com/urllib3/urllib3/issues/2168"
#      42         )
#      43     # fmt: on
#      44
#      45 # === NOTE TO REPACKAGERS AND VENDORS ===
#      46 # Please delete this block, this logic is only
#      47 # for urllib3 being distributed via PyPI.
#      48 # See: https://github.com/urllib3/urllib3/issues/2680
#      49 try:
#
# ImportError: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with LibreSSL 2.8.3. See: https://github.com/urllib3/urllib3/issues/2168
